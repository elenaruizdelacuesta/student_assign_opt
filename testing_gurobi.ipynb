# %%
import gurobipy as gp
print("gurobi ready")
# Out:
# gurobi ready

# %%
m = gp.Model("prueba_licencia")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2824994
# Academic license - for non-commercial use only - expires 2027-05-21
